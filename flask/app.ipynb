# %%
from flask import Flask, request, jsonify, render_template
import poker as p
import series as s

# app = Flask(__name__, static_url_path='/static', static_folder='./static')
app = Flask(__name__, static_url_path='/tfb102flask', static_folder='./tfb102flask')

# @app.route('/')
# def index():
#     return 'Hello Flask!'

@app.route('/')
def index():
    hello = 'Hello Flask 123!'
    return render_template('index.html',
                          hello=hello)

@app.route('/helloFlask/Allen')
def helloFlask1():
    return 'Hello Allen!'

@app.route('/helloFlask/Ted')
def helloFlask2():
    return 'Hello Ted!'

@app.route('/helloFlask/Jack')
def helloFlask3():
    return 'Hello Jack!'

@app.route('/helloFlask/<name>')
def helloFlask(name):
    outStr = 'Hello {}!'
    return outStr.format(name)

@app.route('/addTwoNumber/<x>/<y>') # String
def addTwoNumber(x, y):
    return str(int(x) + int(y))

# @app.route('/hello_get')
# def hello_get():
#     username = request.args.get('username') # string
#     userage = request.args.get('userage')
    
#     if userage == None:
#         return 'Hello {}.'.format(username)
    
#     outStr = 'Hello {} , your are {} years old.'
    
#     return outStr.format(username, userage)

@app.route('/hello_get')
def hello_get():
    username = request.args.get('username') # string
    userage = request.args.get('userage')
    return render_template('hello_get.html',
                          username=username,
                          userage=userage)

# @app.route('/hello_post', methods=['GET', 'POST'])
# def hello_post():
#     outStr = """
#     <form action="/hello_post" method="POST">
#         <label>What's your name?</label>
#         <br>
#         <input name="username">
#         <button type="submit">SUBMIT</button>
#     </form>
#     """
    
#     method = request.method # -> 'GET'/'POST' : String
    
#     if method == 'POST':
#         username = request.form.get('username')
#         outStr += '<h1>Hello {} !</h1>'.format(username)
    
#     return outStr

@app.route('/hello_post', methods=['GET', 'POST'])
def hello_post():
    method = request.method # -> 'GET'/'POST' : String
    
    username = ''
    if method == 'POST':
        username = request.form.get('username')
    
    return render_template('hello_post.html',
                          method=method,
                          username=username)

@app.route('/pokerGame')
def pokerGame():
    playerAmount = int(request.args.get('playerAmount'))
    output = p.poker(playerAmount) # JSON / Dict()
    return jsonify(output)

@app.route('/poker', methods=['GET', 'POST'])
def poker():
    request_method = request.method
    players = 0
    cards = dict()
    if request_method == 'POST':
        players = int(request.form.get('players'))
        cards = p.poker(players)
    return render_template('poker.html', request_method=request_method,
                                         cards=cards)

@app.route('/seriesN')
def seriesN():
    n = int(request.args.get('n'))
    return str(s.Func(n))

if __name__ == '__main__':
    app.run(host='0.0.0.0', port=5000)
# Out:
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on all addresses.
#    WARNING: This is a development server. Do not use it in a production deployment.
#  * Running on http://192.168.50.24:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [05/Jun/2021 14:20:14] "GET /poker HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Jun/2021 14:20:17] "GET /poker HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Jun/2021 14:20:17] "GET /poker HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Jun/2021 14:20:20] "POST /poker HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Jun/2021 14:20:27] "POST /poker HTTP/1.1" 200 -
